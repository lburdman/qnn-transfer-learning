# %%
import sys 
sys.path.append('src')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# OpenMP: number of parallel threads.
# %env OMP_NUM_THREADS=1

# Plotting
# %matplotlib inline
import matplotlib.pyplot as plt

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms

# Pennylane
# from quantum_circuit import q_net, Quantumnet
from quantum_circuit import build_qnode, Quantumnet
import pennylane as qml

# Other tools
import time
import os
import copy

from dataset import get_data_transforms, get_dataloaders
from utils import imshow, plot_tensorboard_metric
from training import train_model, save_model, load_model, visualize_model

from torch.utils.tensorboard import SummaryWriter
# Out:
# env: OMP_NUM_THREADS=1

# %%
n_qubits = 4                     # Number of qubits
quantum = True                   # If set to "False", the dressed quantum circuit is replaced by 
                                 # An enterily classical net (defined by the next parameter). 
classical_model = '512_nq_2'     # Possible choices: '512_2','512_nq_2','551_512_2'. 
step = 0.0004                    # Learning rate
batch_size = 4                   # Number of samples for each training step
num_epochs = 30                  # Number of training epochs
q_depth = 6                      # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1         # Learning rate reduction applied every 10 epochs.                       
max_layers = 15                  # Keep 15 even if not all are used.
q_delta = 0.01                   # Initial spread of random quantum weights
rng_seed = 0                     # Seed for random number generator
start_time = time.time()         # Start of the computation timer

# %%
dev = qml.device('default.qubit', wires=n_qubits)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"✅ Usando dispositivo: {device}")
print(torch.cuda.get_device_name(0))
# Out:
# ✅ Usando dispositivo: cuda:0
# NVIDIA GeForce RTX 4070 Laptop GPU

# %%
data_dir = 'HCQNN/quantum-transfer-learning/data/hymenoptera_data'

data_transforms = get_data_transforms()

torch.manual_seed(rng_seed)

dataloaders, dataset_sizes, class_names = get_dataloaders(
    data_dir=data_dir, batch_size=batch_size, shuffle=True
)

image_datasets = {
    x: dataloaders[x].dataset for x in ['train', 'val']
}

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['val']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
model_hybrid = torchvision.models.resnet18(pretrained=True)

for param in model_hybrid.parameters():
    param.requires_grad = False
    
if quantum:
    model_hybrid.fc = Quantumnet(
        n_qubits=n_qubits,
        q_depth=q_depth,
        max_layers=max_layers,
        q_delta=q_delta,
        dev=dev
    )
    
elif classical_model == '512_2':
    model_hybrid.fc = nn.Linear(512, 2)
    
elif classical_model == '512_nq_2':
    model_hybrid.fc = nn.Sequential(nn.Linear(512, n_qubits), torch.nn.ReLU(), nn.Linear(n_qubits, 2)) 

elif classical_model == '551_512_2':
    model_hybrid.fc = nn.Sequential(nn.Linear(512, 512), torch.nn.ReLU(), nn.Linear(512, 2))

# Use CUDA or CPU according to the "device" object.
model_hybrid = model_hybrid.to(device)

# %%
# Definición de la función de pérdida (loss)
criterion = nn.CrossEntropyLoss()

# Definición del optimizador
optimizer_hybrid = optim.Adam(model_hybrid.fc.parameters(), lr=step)

# Definición del scheduler para reducir el learning rate
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_hybrid, step_size=10, gamma=gamma_lr_scheduler)

# %%
prefix = "q" if quantum else "cl"
timestamp = time.strftime('%Y%m%d_%H%M%S')
log_name = f"{prefix}_ants_bees_resnet18_{timestamp}"

writer = SummaryWriter(log_dir=f"runs/{log_name}")

model_hybrid = train_model(
    model=model_hybrid,
    dataloaders=dataloaders,
    dataset_sizes=dataset_sizes,
    device=device,
    criterion=criterion,
    optimizer=optimizer_hybrid,
    scheduler=exp_lr_scheduler,
    num_epochs=num_epochs, 
    writer=writer
)
writer.close()
# Out:
# 🚀 Training started:
# Phase: train Epoch: 1/30 Loss: 0.3589 Acc: 0.85250.2200s
# Phase: val Epoch: 1/30 Loss: 0.2568 Acc: 0.94120.0364s
# Phase: train Epoch: 2/30 Loss: 0.3195 Acc: 0.87300.2274s
# Phase: val Epoch: 2/30 Loss: 0.2451 Acc: 0.94770.0381s
# Phase: train Epoch: 3/30 Loss: 0.3446 Acc: 0.86480.2092s
# Phase: val Epoch: 3/30 Loss: 0.2410 Acc: 0.95420.0294s
# Phase: train Epoch: 4/30 Loss: 0.3609 Acc: 0.85660.2610s
# Phase: val Epoch: 4/30 Loss: 0.2482 Acc: 0.93460.0300s
# Phase: train Epoch: 5/30 Loss: 0.3477 Acc: 0.86480.1890s
# Phase: val Epoch: 5/30 Loss: 0.2508 Acc: 0.93460.0390s
# Phase: train Epoch: 6/30 Loss: 0.3038 Acc: 0.90570.2098s
# Phase: val Epoch: 6/30 Loss: 0.2555 Acc: 0.93460.0235s
# Phase: train Epoch: 7/30 Loss: 0.2667 Acc: 0.93850.1739s
# Phase: val Epoch: 7/30 Loss: 0.2532 Acc: 0.93460.0305s
# Phase: train Epoch: 8/30 Loss: 0.3355 Acc: 0.86890.1736s
# Phase: val Epoch: 8/30 Loss: 0.2448 Acc: 0.94120.0365s
# Phase: train Epoch: 9/30 Loss: 0.3489 Acc: 0.86480.1679s
# Phase: val Epoch: 9/30 Loss: 0.2511 Acc: 0.93460.0265s
# Phase: train Epoch: 10/30 Loss: 0.3516 Acc: 0.86890.1958s
# Phase: val Epoch: 10/30 Loss: 0.2529 Acc: 0.93460.0272s
# Phase: train Epoch: 11/30 Loss: 0.2946 Acc: 0.90980.1734s
# Phase: val Epoch: 11/30 Loss: 0.2499 Acc: 0.94120.0259s
# Phase: train Epoch: 12/30 Loss: 0.3309 Acc: 0.87700.1744s
# Phase: val Epoch: 12/30 Loss: 0.2443 Acc: 0.94120.0293s
# Phase: train Epoch: 13/30 Loss: 0.2886 Acc: 0.90980.1736s
# Phase: val Epoch: 13/30 Loss: 0.2507 Acc: 0.94770.0273s
# Phase: train Epoch: 14/30 Loss: 0.3146 Acc: 0.87700.1730s
# Phase: val Epoch: 14/30 Loss: 0.2554 Acc: 0.92810.0286s
# Phase: train Epoch: 15/30 Loss: 0.3239 Acc: 0.89340.1977s
# Phase: val Epoch: 15/30 Loss: 0.2502 Acc: 0.94120.0313s
# Phase: train Epoch: 16/30 Loss: 0.2907 Acc: 0.91390.2007s
# Phase: val Epoch: 16/30 Loss: 0.2533 Acc: 0.93460.0399s
# Phase: train Epoch: 17/30 Loss: 0.2939 Acc: 0.89750.1789s
# Phase: val Epoch: 17/30 Loss: 0.2481 Acc: 0.94770.0333s
# Phase: train Epoch: 18/30 Loss: 0.3078 Acc: 0.88110.1853s
# Phase: val Epoch: 18/30 Loss: 0.2486 Acc: 0.94120.0311s
# Phase: train Epoch: 19/30 Loss: 0.3011 Acc: 0.88930.1737s
# Phase: val Epoch: 19/30 Loss: 0.2520 Acc: 0.94120.0295s
# Phase: train Epoch: 20/30 Loss: 0.3440 Acc: 0.86070.1976s
# Phase: val Epoch: 20/30 Loss: 0.2430 Acc: 0.94120.0333s
# Phase: train Epoch: 21/30 Loss: 0.3913 Acc: 0.82790.1954s
# Phase: val Epoch: 21/30 Loss: 0.2566 Acc: 0.94120.0370s
# Phase: train Epoch: 22/30 Loss: 0.3443 Acc: 0.86070.1917s
# Phase: val Epoch: 22/30 Loss: 0.2453 Acc: 0.94120.0439s
# Phase: train Epoch: 23/30 Loss: 0.3590 Acc: 0.85250.1888s
# Phase: val Epoch: 23/30 Loss: 0.2471 Acc: 0.95420.0211s
# Phase: train Epoch: 24/30 Loss: 0.2892 Acc: 0.89750.1738s
# Phase: val Epoch: 24/30 Loss: 0.2496 Acc: 0.94770.0354s
# Phase: train Epoch: 25/30 Loss: 0.3064 Acc: 0.89340.1917s
# Phase: val Epoch: 25/30 Loss: 0.2515 Acc: 0.94120.0292s
# Phase: train Epoch: 26/30 Loss: 0.3266 Acc: 0.87700.1721s
# Phase: val Epoch: 26/30 Loss: 0.2436 Acc: 0.94120.0353s
# Phase: train Epoch: 27/30 Loss: 0.3484 Acc: 0.86480.1812s
# Phase: val Epoch: 27/30 Loss: 0.2478 Acc: 0.93460.0274s
# Phase: train Epoch: 28/30 Loss: 0.2878 Acc: 0.91390.2136s
# Phase: val Epoch: 28/30 Loss: 0.2427 Acc: 0.94770.0292s
# Phase: train Epoch: 29/30 Loss: 0.3508 Acc: 0.85250.1829s
# Phase: val Epoch: 29/30 Loss: 0.2429 Acc: 0.94770.0361s
# Phase: train Epoch: 30/30 Loss: 0.3172 Acc: 0.89340.2262s
# Phase: val Epoch: 30/30 Loss: 0.2454 Acc: 0.94120.0254s
# ✅ Entrenamiento finalizado en 8m 47s
# 🎯 Mejor loss (val): 0.2410 | Mejor accuracy (val): 0.9542

# %%
plot_tensorboard_metric("q_ants_bees_resnet18_20250516_165016", metric="Loss", phase="train")
plot_tensorboard_metric("q_ants_bees_resnet18_20250516_165016", metric="Loss", phase="val")
plot_tensorboard_metric("q_ants_bees_resnet18_20250516_165016", metric="Accuracy", phase="train")
plot_tensorboard_metric("q_ants_bees_resnet18_20250516_165016", metric="Accuracy", phase="val")

# %%
model_name = "ants_bees_resnet18_0"
save_model(model_hybrid, quantum=quantum, name=model_name)
# Out:
# 💾 Modelo guardado en: models\q_ants_bees_resnet18_0_quantum.pt
